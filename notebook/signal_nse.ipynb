# %%
import os
import pandas as pd
import ta
from typing import List
from IPython.display import display, HTML

# %%
def display_scrollable_df(df, max_rows=25, max_cols=10, width="100%", height="500px"):
    display(HTML(df.to_html(
        max_rows=max_rows,
        max_cols=max_cols,
        escape=False,
        notebook=True
    ).replace('<table ', f'<div style="overflow:auto; width:{width}; height:{height}"><table ')
     + '</div>'))

# %%
ohlcv_map = {
    'date': 'TradDt',
    'symbol': 'TckrSymb',
    'open': 'OpnPric',
    'high': 'HghPric',
    'low': 'LwPric',
    'close': 'ClsPric',
    'volume': 'TtlTradgVol'
}

# %%
def list_csv_gz_files(base_dir: str):
    file_list = []
    for root, _, files in os.walk(base_dir):
        for file in files:
            if file.endswith('.csv.gz'):
                file_list.append(os.path.join(root, file))
    return sorted(file_list)

# %%
def load_rolling_window(file_list: List[str], window_size: int) -> pd.DataFrame:
    required_cols = set(ohlcv_map.values())
    recent_files = file_list[:window_size]
    dfs = []

    for file_path in recent_files:
        try:
            df = pd.read_csv(file_path, compression='gzip')
        except Exception as e:
            if verbose:
                print(f"[ERROR] Failed to read {file_path}: {e}")
            continue

        if df.empty:
            if verbose:
                print(f"[INFO] Skipping empty file: {file_path}")
            continue

        missing_cols = required_cols - set(df.columns)
        if missing_cols:
            if verbose:
                print(f"[WARNING] Missing columns {missing_cols} in {file_path}, skipping.")
            continue

        # Ensure date is in datetime format
        df[ohlcv_map['date']] = pd.to_datetime(df[ohlcv_map['date']])

        dfs.append(df)

    if not dfs:
        if verbose:
            print("[INFO] No valid files loaded.")
        return pd.DataFrame()

    combined_df = pd.concat(dfs, ignore_index=True)

    # Sort by stock and date
    combined_df.sort_values(by=[ohlcv_map['symbol'], ohlcv_map['date']], inplace=True)

    return combined_df

# %%
def compute_indicators(df: pd.DataFrame) -> pd.DataFrame:
    # Step 1: Keep only required columns
    df = df[['TradDt', 'TckrSymb', 'OpnPric', 'HghPric', 'LwPric', 'ClsPric', 'TtlTradgVol']].copy()

    # Step 2: Rename columns
    df.columns = ['Date', 'Symbol', 'Open', 'High', 'Low', 'Close', 'Volume']
    df['Date'] = pd.to_datetime(df['Date'])
    df.sort_values(by=['Symbol', 'Date'], inplace=True)

    # Step 3: Group by Symbol and compute indicators
    results = []

    for symbol, group in df.groupby('Symbol'):
        g = group.copy()
        g.set_index('Date', inplace=True)

        # === Lagging Indicators ===
        g['EMA_20'] = ta.trend.EMAIndicator(close=g['Close'], window=20).ema_indicator()
        g['EMA_50'] = ta.trend.EMAIndicator(close=g['Close'], window=50).ema_indicator()
        
        macd = ta.trend.MACD(close=g['Close'], window_slow=26, window_fast=12, window_sign=9)
        g['MACD'] = macd.macd()
        g['MACD_signal'] = macd.macd_signal()
        g['MACD_hist'] = macd.macd_diff()

        bb = ta.volatility.BollingerBands(close=g['Close'], window=20, window_dev=2)
        g['BB_upper'] = bb.bollinger_hband()
        g['BB_lower'] = bb.bollinger_lband()
        g['BB_width'] = bb.bollinger_wband()

        # === Leading Indicators ===
        g['RSI_14'] = ta.momentum.RSIIndicator(close=g['Close'], window=14).rsi()
        g['MFI_14'] = ta.volume.MFIIndicator(high=g['High'], low=g['Low'], close=g['Close'], volume=g['Volume'], window=14).money_flow_index()
        g['STOCH_K'] = ta.momentum.StochasticOscillator(high=g['High'], low=g['Low'], close=g['Close']).stoch()
        g['STOCH_D'] = ta.momentum.StochasticOscillator(high=g['High'], low=g['Low'], close=g['Close']).stoch_signal()
        g['CCI'] = ta.trend.CCIIndicator(high=g['High'], low=g['Low'], close=g['Close'], window=20).cci()
        g['WILLIAMS_R'] = ta.momentum.WilliamsRIndicator(high=g['High'], low=g['Low'], close=g['Close'], lbp=14).williams_r()
        
        g.reset_index(inplace=True) 
        results.append(g) 

    # Step 4: Concatenate all symbols
    final_df = pd.concat(results, ignore_index=True)

    # ✅ Ensure 'Date' exists and filter latest date only
    if 'Date' in final_df.columns:
        latest_date = final_df['Date'].max()
        final_df = final_df[final_df['Date'] == latest_date]
    else:
        raise KeyError("❌ 'Date' column missing after groupby processing.")

    # Step 5: Select only final columns
    final_columns = [
        'Date', 'Symbol', 'Open', 'High', 'Low', 'Close', 'Volume',
        'EMA_20', 'EMA_50', 'MACD', 'MACD_signal', 'MACD_hist',
        'BB_upper', 'BB_lower', 'BB_width',
        'RSI_14', 'MFI_14', 'STOCH_K', 'STOCH_D', 'CCI', 'WILLIAMS_R'
    ]
    return final_df[final_columns]

# %%
def generate_signals(df: pd.DataFrame, signal_dir: str = "signal", save_scores: bool = False) -> None:
    """
    Generate Buy/Hold/Sell signals using improved graded scoring logic and save compressed CSV file.

    Args:
        df (pd.DataFrame): Input DataFrame containing technical indicators.
        signal_dir (str): Output directory to save signals.
        save_scores (bool): Whether to store leading/lagging scores in output for debugging.
    """

    df = df.copy()
    signals = []
    leading_score_list = []
    lagging_score_list = []

    for _, row in df.iterrows():
        symbol = row['Symbol']
        leading_score = 0
        lagging_score = 0

        # === Leading Indicators ===
        if row['RSI_14'] < 30:
            leading_score += 1
        if row['MFI_14'] < 20:
            leading_score += 1
        if row['STOCH_K'] < 20 and row['STOCH_K'] > row['STOCH_D']:
            leading_score += 1
        if row['CCI'] < -100:
            leading_score += 1
        if row['WILLIAMS_R'] < -80:
            leading_score += 1

        # === Lagging Indicators ===
        if row['EMA_20'] > row['EMA_50']:
            lagging_score += 1
        if row['MACD'] > row['MACD_signal']:
            lagging_score += 1
        # Use normalized BB width
        if row['BB_width'] / max(row['Close'], 1) > 0.06:
            lagging_score += 1
        # Optional: Add close > EMA_20 confirmation
        if row['Close'] > row.get('EMA_20', 0):
            lagging_score += 1

        # === Decision Logic ===
        if leading_score >= 3 and lagging_score >= 2:
            signal = 'BUY'
        elif leading_score <= 1 and lagging_score <= 1:
            signal = 'SELL'
        else:
            signal = 'HOLD'

        signals.append(signal)
        leading_score_list.append(leading_score)
        lagging_score_list.append(lagging_score)

    # Append signals and scores
    df['Signal'] = signals
    if save_scores:
        df['Leading_Score'] = leading_score_list
        df['Lagging_Score'] = lagging_score_list

    # Final column order
    output_cols = ['Date', 'Symbol', 'Open', 'High', 'Low', 'Close', 'Volume'] + \
                  [col for col in df.columns if col not in ['Date', 'Symbol', 'Open', 'High', 'Low', 'Close', 'Volume']]

    output_df = df[output_cols]
    output_df.sort_values(by=['Symbol'], inplace=True)

    # Save output
    last_date = pd.to_datetime(df['Date'].max())
    year_str = last_date.strftime("%Y")
    date_str = last_date.strftime("%Y%m%d")
    output_path = os.path.join(signal_dir, year_str)
    os.makedirs(output_path, exist_ok=True)
    file_name = f"{date_str}.csv"
    full_path = os.path.join(output_path, file_name)

    output_df.to_csv(full_path, index=False)
    print(f"✅ Signal file saved to: {full_path}")

    # Optional: print sample debug
    print("\n🔍 Sample Signal Debug:")
    print(output_df[['Symbol', 'Signal'] + (['Leading_Score', 'Lagging_Score'] if save_scores else [])].head(5))

# %%
def generate_signals_rolling(
    data_dir: str = "../data/nse/equity",
    window_size: int = 60,
    signal_dir: str = "../signal/nse/equity"
) -> None:
    """
    Walk backward through daily files using a rolling window to compute EOD signals.
    Saves signal for the latest date in each window, then pops and continues.
    Stops when < window_size files remain.
    """

    # Step 1: Sort latest to earliest
    all_files = list_csv_gz_files(data_dir)
    all_files = sorted(all_files, reverse=True)
    
          
    print(f"📂 Total files: {len(all_files)} | Starting rolling window generation...")

    # Step 2: Loop until fewer than 14 files remain
    while len(all_files) >= 14:
        
        try:
            # Step 3: Load data for this window
            df_window = load_rolling_window(all_files, window_size)

            # Step 4: Compute indicators, retain only last day per symbol
            df_indicators = compute_indicators(df_window)

            # Step 5: Generate and save signal
            generate_signals(df_indicators, signal_dir=signal_dir)

        except Exception as e:
            print(f"⚠️ Skipping date {all_files[0]} due to error: {e}")

        # Step 6: Pop the latest file (T), move window back one day
        all_files.pop(0)

    print("✅ Rolling signal generation complete.")

# %%
generate_signals_rolling()
# Out:
# 📂 Total files: 174 | Starting rolling window generation...
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250912.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 30       0SCL26   SELL
# 130  1003SCL30A   SELL
# 133  1003SCL31P   SELL
# 153  1003SFIL28   SELL
# 212  1015SCFL29   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250911.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 108  1003ISFL28   HOLD
# 151  1003SFIL28   SELL
# 208   1015ECL29   HOLD
# 311   1015UCL27   SELL
# 362  1018GS2026   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250910.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 6      0MOFSL26   SELL
# 29       0SCL26   SELL
# 108  1003ISFL28   HOLD
# 130  1003SCL30A   SELL
# 208   1015ECL29   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250909.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 13     0MOFSL27   SELL
# 106  1003ISFL28   HOLD
# 148  1003SFIL28   SELL
# 204   1015ECL29   HOLD
# 276   1015UCL26   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250908.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 107  1003ISFL28   HOLD
# 129  1003SCL30A   SELL
# 206   1015ECL29   HOLD
# 232   1015SCL29   SELL
# 278   1015UCL26   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250905.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 6      0MOFSL26   SELL
# 36       0SCL27   SELL
# 109  1003ISFL28   HOLD
# 207   1015ECL29   HOLD
# 232   1015SCL29   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250904.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 29       0SCL26   SELL
# 56   1003IIFL29   SELL
# 151  1003SFIL28   SELL
# 207   1015ECL29   HOLD
# 278   1015UCL26   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250903.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 107  1003ISFL28   HOLD
# 130  1003SCL30A   SELL
# 150  1003SFIL28   SELL
# 206   1015ECL29   HOLD
# 243  1015SCL29T   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250902.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 110  1003ISFL28   HOLD
# 133  1003SCL30A   SELL
# 208   1015ECL29   HOLD
# 310   1015UCL27   SELL
# 361  1018GS2026   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250901.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 29       0SCL26   SELL
# 111  1003ISFL28   SELL
# 133  1003SCL30A   SELL
# 208   1015ECL29   HOLD
# 226  1015SCL28A   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250829.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 35       0SCL27   SELL
# 112  1003ISFL28   SELL
# 133  1003SCL30A   SELL
# 135  1003SCL31A   SELL
# 153  1003SFIL28   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250828.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 111  1003ISFL28   SELL
# 205   1015ECL29   HOLD
# 276   1015UCL26   HOLD
# 304   1015UCL27   SELL
# 353  1018GS2026   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250826.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 151  1003SFIL28   SELL
# 207   1015ECL29   HOLD
# 231   1015SCL29   SELL
# 305   1015UCL27   SELL
# 354  1018GS2026   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250825.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 18     0MOFSL27   SELL
# 31       0SCL26   SELL
# 208   1015ECL29   HOLD
# 225  1015SCL28A   SELL
# 304   1015UCL27   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250822.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 29       0SCL26   SELL
# 113  1003ISFL28   SELL
# 207   1015ECL29   HOLD
# 301   1015UCL27   SELL
# 350  1018GS2026   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250821.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 34       0SCL27   SELL
# 206   1015ECL29   SELL
# 241  1015SCL29T   SELL
# 277   1015UCL26   SELL
# 301   1015UCL27   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250820.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 5      0MOFSL26   SELL
# 57   1003IIFL29   SELL
# 111  1003ISFL28   SELL
# 132  1003SCL30A   SELL
# 206   1015ECL29   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250819.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 109  1003ISFL28   SELL
# 203   1015ECL29   HOLD
# 225   1015SCL29   SELL
# 270   1015UCL26   SELL
# 292   1015UCL27   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250818.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 110  1003SCFL31   SELL
# 147  1003SFIL28   SELL
# 203   1015ECL29   HOLD
# 342  1018GS2026   SELL
# 378   1025NFL25   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250814.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 27       0SCL26   SELL
# 110  1003ISFL28   SELL
# 147  1003SFIL28   SELL
# 203   1015ECL29   HOLD
# 225   1015SCL29   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250813.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 110  1003ISFL28   SELL
# 202   1015ECL29   HOLD
# 271   1015UCL26   SELL
# 292   1015UCL27   SELL
# 345  1018GS2026   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250812.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 4      0MOFSL26   SELL
# 27       0SCL26   SELL
# 203   1015ECL29   HOLD
# 273   1015UCL26   SELL
# 346  1018GS2026   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250811.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 16     0MOFSL27   SELL
# 110  1003ISFL28   HOLD
# 131   1003SCL31   SELL
# 202   1015ECL29   HOLD
# 226   1015SCL29   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250808.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 30       0SCL27   SELL
# 111  1003ISFL28   HOLD
# 202   1015ECL29   HOLD
# 343  1018GS2026   HOLD
# 380   1025NFL25   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250807.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 25       0SCL26   SELL
# 112  1003ISFL28   SELL
# 147  1003SFIL28   SELL
# 203   1015ECL29   SELL
# 273   1015UCL26   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250806.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 57   1003IIFL29   SELL
# 111  1003ISFL28   SELL
# 132  1003SCL30A   SELL
# 204   1015ECL29   SELL
# 206  1015SCFL29   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250805.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 57   1003IIFL29   SELL
# 111  1003ISFL28   SELL
# 132  1003SCL30A   SELL
# 205   1015ECL29   HOLD
# 274   1015UCL26   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250804.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 18     0MOFSL27   HOLD
# 58   1003IIFL29   HOLD
# 112  1003ISFL28   SELL
# 207  1015SCFL29   SELL
# 346  1018GS2026   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250801.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 59   1003IIFL29   SELL
# 113  1003ISFL28   SELL
# 133  1003SCL30A   SELL
# 245  1015SCL29T   SELL
# 279   1015UCL26   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250731.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 59   1003IIFL29   HOLD
# 112  1003ISFL28   HOLD
# 131  1003SCL30A   SELL
# 207   1015ECL29   HOLD
# 223  1015SCL28A   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250730.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 58   1003IIFL29   SELL
# 111  1003ISFL28   HOLD
# 129  1003SCL30A   SELL
# 205   1015ECL29   HOLD
# 220  1015SCL28A   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250729.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 57   1003IIFL29   SELL
# 110  1003ISFL28   HOLD
# 203   1015ECL29   HOLD
# 217  1015SCL28A   SELL
# 270   1015UCL26   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250728.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 20     0MOFSL27   SELL
# 109  1003ISFL28   HOLD
# 126  1003SCL30A   SELL
# 203   1015ECL29   HOLD
# 216  1015SCL28A   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250725.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 58   1003IIFL29   SELL
# 110  1003ISFL28   HOLD
# 203   1015ECL29   HOLD
# 216  1015SCL28A   SELL
# 285   1015UCL27   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250724.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 29       0SCL26   SELL
# 109  1003ISFL28   HOLD
# 125  1003SCL30A   SELL
# 202   1015ECL29   HOLD
# 214  1015SCL28A   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250723.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 57   1003IIFL29   SELL
# 109  1003ISFL28   HOLD
# 203   1015ECL29   HOLD
# 215  1015SCL28A   SELL
# 267   1015UCL26   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250722.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 34       0SCL27   SELL
# 108  1003ISFL28   HOLD
# 203   1015ECL29   HOLD
# 214  1015SCL28A   SELL
# 225  1015SCL29B   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250721.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 107  1003ISFL28   HOLD
# 145  1003SFIL28   SELL
# 203   1015ECL29   HOLD
# 262   1015UCL26   SELL
# 329  1018GS2026   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250718.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 20     0MOFSL27   SELL
# 106  1003ISFL28   HOLD
# 145  1003SFIL28   SELL
# 203   1015ECL29   HOLD
# 262   1015UCL26   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250717.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 54   1003IIFL29   SELL
# 105  1003ISFL28   HOLD
# 202   1015ECL29   HOLD
# 276   1015UCL27   SELL
# 329  1018GS2026   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250716.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 27       0SCL26   SELL
# 53   1003IIFL29   SELL
# 104  1003ISFL28   HOLD
# 203   1015ECL29   HOLD
# 263   1015UCL26   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250715.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 101  1003ISFL28   HOLD
# 121  1003SCL30A   SELL
# 201   1015ECL29   HOLD
# 326  1018GS2026   HOLD
# 333  1025IIFL30   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250714.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 6      0MOFSL26   SELL
# 32       0SCL27   SELL
# 202   1015ECL29   HOLD
# 220   1015SCL29   SELL
# 224  1015SCL29B   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250711.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 19     0MOFSL27   SELL
# 103  1003ISFL28   SELL
# 122  1003SCL30A   SELL
# 203   1015ECL29   SELL
# 261   1015UCL26   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250710.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 18     0MOFSL27   SELL
# 103  1003ISFL28   HOLD
# 146  1003SFIL28   HOLD
# 204   1015ECL29   HOLD
# 271   1015UCL27   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250709.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 52   1003IIFL29   SELL
# 103  1003ISFL28   HOLD
# 123  1003SCL30A   SELL
# 147  1003SFIL28   SELL
# 205   1015ECL29   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250708.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 105  1003ISFL28   HOLD
# 124  1003SCL30A   SELL
# 148  1003SFIL28   SELL
# 206   1015ECL29   HOLD
# 216  1015SCL28A   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250707.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 106  1003ISFL28   HOLD
# 149  1003SFIL28   SELL
# 207   1015ECL29   HOLD
# 216  1015SCL28A   SELL
# 267   1015UCL27   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250704.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 57   1003IIFL29   SELL
# 108  1003ISFL28   SELL
# 150  1003SFIL28   SELL
# 208   1015ECL29   HOLD
# 260   1015UCL26   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250703.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 5      0MOFSL26   SELL
# 108  1003ISFL28   HOLD
# 150  1003SFIL28   HOLD
# 208   1015ECL29   HOLD
# 376  1025SCL34A   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250702.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 28       0SCL26   SELL
# 56   1003IIFL29   SELL
# 107  1003ISFL28   HOLD
# 207   1015ECL29   HOLD
# 267   1015UCL27   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250701.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 55   1003IIFL29   SELL
# 106  1003ISFL28   HOLD
# 207   1015ECL29   SELL
# 268   1015UCL27   SELL
# 323  1018GS2026   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250630.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 55   1003IIFL29   SELL
# 106  1003ISFL28   SELL
# 207   1015ECL29   SELL
# 323  1018GS2026   HOLD
# 481  1025UCL26A   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250627.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 21        0RL34   SELL
# 55   1003IIFL29   SELL
# 106  1003ISFL28   HOLD
# 150  1003SFIL28   HOLD
# 208   1015ECL29   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250626.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 20        0RL34   SELL
# 54   1003IIFL29   SELL
# 105  1003ISFL28   HOLD
# 126  1003SCL30A   SELL
# 207   1015ECL29   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250625.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 19        0RL34   SELL
# 53   1003IIFL29   SELL
# 206   1015ECL29   HOLD
# 212   1015SCL28   SELL
# 265   1015UCL27   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250624.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 18        0RL34   SELL
# 102  1003ISFL28   SELL
# 122  1003SCL30A   SELL
# 204   1015ECL29   HOLD
# 259   1015UCL26   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250623.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 103  1003ISFL28   SELL
# 204   1015ECL29   HOLD
# 258   1015UCL26   SELL
# 314  1018GS2026   SELL
# 369  1025SCL34A   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250620.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 5      0MOFSL26   SELL
# 104  1003ISFL28   SELL
# 313  1018GS2026   HOLD
# 368  1025SCL34A   SELL
# 546   1035UCL26   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250619.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 104  1003ISFL28   SELL
# 148  1003SFIL28   SELL
# 206   1015ECL29   HOLD
# 259   1015UCL26   SELL
# 315  1018GS2026   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250618.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 105  1003ISFL28   SELL
# 149  1003SFIL28   HOLD
# 207   1015ECL29   HOLD
# 315  1018GS2026   SELL
# 368   1025SCL34   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250617.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 105  1003ISFL28   SELL
# 124  1003SCL30A   SELL
# 207   1015ECL29   HOLD
# 212   1015SCL28   SELL
# 222  1015SCL29B   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250616.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 104  1003ISFL28   SELL
# 256   1015UCL26   SELL
# 312  1018GS2026   HOLD
# 348   1025NFL25   HOLD
# 370  1025SCL34A   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250613.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 4      0MOFSL26   SELL
# 19     0MOFSL27   SELL
# 105  1003ISFL28   HOLD
# 124  1003SCL30A   SELL
# 127  1003SCL31P   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250612.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 17     0MOFSL27   SELL
# 23       0SCL26   SELL
# 103  1003ISFL28   HOLD
# 208   1015ECL29   HOLD
# 313  1018GS2026   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250611.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 55   1003IIFL29   SELL
# 103  1003ISFL28   HOLD
# 122  1003SCL30A   SELL
# 210   1015ECL29   HOLD
# 213   1015SCL28   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250610.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 102  1003ISFL28   HOLD
# 121  1003SCL30A   SELL
# 210   1015ECL29   HOLD
# 258   1015UCL26   SELL
# 314  1018GS2026   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250609.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 18     0MOFSL27   SELL
# 29       0SCL27   SELL
# 55   1003IIFL29   SELL
# 103  1003ISFL28   HOLD
# 121  1003SCL30A   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250606.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 52   1003IIFL29   SELL
# 100  1003ISFL28   HOLD
# 207   1015ECL29   HOLD
# 253   1015UCL26   SELL
# 416  1025SCL35A   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250605.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 17     0MOFSL27   SELL
# 51   1003IIFL29   SELL
# 99   1003ISFL28   HOLD
# 149  1003SFIL28   SELL
# 207   1015ECL29   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250604.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 97   1003ISFL28   HOLD
# 204   1015ECL29   HOLD
# 249   1015UCL26   SELL
# 307  1018GS2026   HOLD
# 460  1025UCL26A   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250603.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 17     0MOFSL27   SELL
# 98   1003ISFL28   HOLD
# 116  1003SCL30A   SELL
# 206   1015ECL29   HOLD
# 251   1015UCL26   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250602.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 17     0MOFSL27   SELL
# 98   1003ISFL28   HOLD
# 206   1015ECL29   HOLD
# 308  1018GS2026   HOLD
# 368   1025SCL34   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250530.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 97   1003ISFL28   HOLD
# 205   1015ECL29   SELL
# 308  1018GS2026   HOLD
# 347   1025NFL25   SELL
# 386  1025SCL34B   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250529.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 26       0SCL27   SELL
# 205   1015ECL29   SELL
# 216  1015SCL28B   SELL
# 226  1015SCL29T   SELL
# 309  1018GS2026   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250528.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 149  1003SFIL28   HOLD
# 207   1015ECL29   SELL
# 226  1015SCL29T   SELL
# 309  1018GS2026   HOLD
# 533   1035UCL26   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250527.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 101  1003ISFL28   HOLD
# 209   1015ECL29   SELL
# 311  1018GS2026   HOLD
# 348   1025NFL25   SELL
# 371   1025SCL34   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250526.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 102  1003ISFL28   HOLD
# 210   1015ECL29   SELL
# 255   1015UCL26   SELL
# 313  1018GS2026   HOLD
# 349   1025NFL25   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250523.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 103  1003ISFL28   HOLD
# 121  1003SCL30A   SELL
# 210   1015ECL29   HOLD
# 216  1015SCL28A   SELL
# 254   1015UCL26   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250522.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 55   1003IIFL29   SELL
# 105  1003ISFL28   HOLD
# 211   1015ECL29   SELL
# 217  1015SCL28A   SELL
# 254   1015UCL26   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250521.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 18     0MOFSL27   SELL
# 105  1003ISFL28   SELL
# 211   1015ECL29   SELL
# 221  1015SCL28B   SELL
# 253   1015UCL26   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250520.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 56   1003IIFL29   SELL
# 214   1015ECL29   SELL
# 223  1015SCL28B   SELL
# 255   1015UCL26   SELL
# 312  1018GS2026   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250519.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 5      0MOFSL26   SELL
# 56   1003IIFL29   SELL
# 107  1003ISFL28   HOLD
# 216   1015ECL29   SELL
# 255   1015UCL26   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250516.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 27       0SCL27   SELL
# 55   1003IIFL29   SELL
# 106  1003ISFL28   HOLD
# 214   1015ECL29   SELL
# 310  1018GS2026   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250515.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 19     0MOFSL27   SELL
# 124  1003SCL30A   SELL
# 128   1003SCL31   SELL
# 158  1003SFIL28   HOLD
# 214   1015ECL29   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250514.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 55   1003IIFL29   SELL
# 107  1003ISFL28   HOLD
# 124  1003SCL30A   SELL
# 156  1003SFIL28   SELL
# 212   1015ECL29   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250513.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 18     0MOFSL27   SELL
# 56   1003IIFL29   SELL
# 108  1003ISFL28   HOLD
# 155  1003SFIL28   SELL
# 211   1015ECL29   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250512.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 6      0MOFSL26   SELL
# 19     0MOFSL27   SELL
# 24       0SCL26   SELL
# 108  1003ISFL28   HOLD
# 210   1015ECL29   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250509.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 6      0MOFSL26   SELL
# 211   1015ECL29   SELL
# 247   1015UCL27   SELL
# 304  1018GS2026   HOLD
# 333   1025NFL25   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250508.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 112  1003ISFL28   HOLD
# 215   1015ECL29   SELL
# 228  1015SCL29T   SELL
# 250   1015UCL26   SELL
# 307  1018GS2026   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250507.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 115  1003ISFL28   SELL
# 218   1015ECL29   SELL
# 230  1015SCL29T   SELL
# 360   1025SCL34   SELL
# 409  1025SCL35A   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250506.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 117  1003ISFL28   SELL
# 164  1003SFIL28   HOLD
# 220   1015ECL29   HOLD
# 312  1018GS2026   SELL
# 413  1025SCL35A   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250505.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 23     0MOFSL27   SELL
# 33       0SCL27   SELL
# 66   1003IIFL29   HOLD
# 221   1015ECL29   HOLD
# 223   1015SCL28   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250502.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 118  1003ISFL28   HOLD
# 220   1015ECL29   SELL
# 230  1015SCL29T   SELL
# 312  1018GS2026   HOLD
# 381  1025SCL34B   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250430.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 66   1003IIFL29   SELL
# 120  1003ISFL28   HOLD
# 136  1003SCL30A   SELL
# 166  1003SFIL28   HOLD
# 222   1015ECL29   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250429.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 122  1003ISFL28   HOLD
# 137  1003SCL30A   SELL
# 222   1015ECL29   SELL
# 230  1015SCL29T   SELL
# 312  1018GS2026   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250428.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 124  1003ISFL28   HOLD
# 167  1003SFIL28   HOLD
# 223   1015ECL29   SELL
# 311  1018GS2026   HOLD
# 336   1025NFL25   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250425.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 141  1003SCL30A   SELL
# 169  1003SFIL28   SELL
# 225   1015ECL29   SELL
# 230  1015SCL28B   SELL
# 313  1018GS2026   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250424.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 130  1003ISFL28   HOLD
# 171  1003SFIL28   SELL
# 227   1015ECL29   SELL
# 231  1015SCL28B   SELL
# 256   1015UCL26   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250423.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 134  1003ISFL28   HOLD
# 147  1003SCL30A   SELL
# 174  1003SFIL28   SELL
# 230   1015ECL29   SELL
# 315  1018GS2026   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250422.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 147  1003SCL30A   SELL
# 231   1015ECL29   SELL
# 317  1018GS2026   SELL
# 341   1025NFL25   SELL
# 406  1025SCL35A   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250421.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 31     0MOFSL27   SELL
# 84   1003IIFL29   HOLD
# 138  1003ISFL28   HOLD
# 236   1015ECL29   SELL
# 323  1018GS2026   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250417.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 44       0SCL27   SELL
# 137  1003ISFL28   HOLD
# 180  1003SFIL28   SELL
# 236   1015ECL29   HOLD
# 266   1015UCL26   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250416.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 42       0SCL26   SELL
# 138  1003ISFL28   HOLD
# 152  1003SCL30A   SELL
# 181  1003SFIL28   SELL
# 237   1015ECL29   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250415.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 86   1003IIFL29   SELL
# 140  1003ISFL28   HOLD
# 153  1003SCL30A   SELL
# 182  1003SFIL28   HOLD
# 238   1015ECL29   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250411.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 44       0SCL26   SELL
# 47       0SCL27   SELL
# 87   1003IIFL29   SELL
# 141  1003ISFL28   SELL
# 182  1003SFIL28   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250409.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 36     0MOFSL27   SELL
# 141  1003ISFL28   SELL
# 153  1003SCL30A   SELL
# 181  1003SFIL28   SELL
# 237   1015ECL29   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250408.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 45       0SCL26   SELL
# 87   1003IIFL29   SELL
# 141  1003ISFL28   HOLD
# 236   1015ECL29   HOLD
# 268   1015UCL26   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250407.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 44       0SCL26   SELL
# 140  1003ISFL28   SELL
# 180  1003SFIL28   SELL
# 236   1015ECL29   HOLD
# 242  1015SCL29T   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250404.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 141  1003ISFL28   HOLD
# 153  1003SCL30A   SELL
# 237   1015ECL29   HOLD
# 325  1018GS2026   HOLD
# 347   1025NFL25   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250403.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 89   1003IIFL29   SELL
# 143  1003ISFL28   HOLD
# 154  1003SCL30A   SELL
# 239   1015ECL29   HOLD
# 245   1015SCL30   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250402.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 90   1003IIFL29   SELL
# 144  1003ISFL28   HOLD
# 239   1015ECL29   SELL
# 268   1015UCL26   SELL
# 326  1018GS2026   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250401.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 91   1003IIFL29   HOLD
# 145  1003ISFL28   HOLD
# 186  1003SFIL28   SELL
# 242   1015ECL29   SELL
# 270   1015UCL26   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250328.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 91   1003IIFL29   HOLD
# 145  1003ISFL28   SELL
# 186  1003SFIL28   SELL
# 242   1015ECL29   HOLD
# 330  1018GS2026   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250327.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 91   1003IIFL29   HOLD
# 145  1003ISFL28   HOLD
# 186  1003SFIL28   SELL
# 242   1015ECL29   HOLD
# 331  1018GS2026   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250326.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 238   1015ECL29   SELL
# 326  1018GS2026   HOLD
# 346   1025NFL25   SELL
# 404  1025SCL35A   SELL
# 517   1040NFL26   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250325.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 40     0MOFSL27   SELL
# 90   1003IIFL29   HOLD
# 143  1003ISFL28   SELL
# 237   1015ECL29   HOLD
# 324  1018GS2026   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250324.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 19     0MOFSL26   SELL
# 140  1003ISFL28   SELL
# 319  1018GS2026   HOLD
# 337   1025NFL25   SELL
# 393  1025SCL35A   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250321.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 38     0MOFSL27   SELL
# 138  1003ISFL28   SELL
# 154   1003SCL31   SELL
# 231   1015ECL29   HOLD
# 316  1018GS2026   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250320.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 86   1003IIFL29   SELL
# 136  1003ISFL28   SELL
# 175  1003SFIL28   SELL
# 227   1015ECL29   HOLD
# 311  1018GS2026   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250319.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 85   1003IIFL29   HOLD
# 172  1003SFIL28   SELL
# 223   1015ECL29   HOLD
# 306  1018GS2026   HOLD
# 321   1025NFL25   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250318.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 170  1003SFIL28   SELL
# 220   1015ECL29   HOLD
# 302  1018GS2026   HOLD
# 316   1025NFL25   SELL
# 341   1025SCL34   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250317.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 84   1003IIFL29   SELL
# 133  1003ISFL28   HOLD
# 136  1003SCFL31   SELL
# 169  1003SFIL28   HOLD
# 218   1015ECL29   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250313.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 83   1003IIFL29   SELL
# 133  1003SCFL31   SELL
# 165  1003SFIL28   HOLD
# 213   1015ECL29   SELL
# 292  1018GS2026   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250312.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 37     0MOFSL27   SELL
# 82   1003IIFL29   HOLD
# 130  1003ISFL28   SELL
# 143   1003SCL31   SELL
# 162  1003SFIL28   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250311.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 127  1003ISFL28   SELL
# 128  1003SCFL31   SELL
# 139   1003SCL31   SELL
# 203   1015ECL29   SELL
# 233   1015UCL26   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250310.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 36     0MOFSL27   SELL
# 126  1003ISFL28   HOLD
# 154  1003SFIL28   SELL
# 199   1015ECL29   SELL
# 274  1018GS2026   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250307.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 124  1003ISFL28   HOLD
# 151  1003SFIL28   HOLD
# 224   1015UCL26   SELL
# 269  1018GS2026   SELL
# 301   1025SCL34   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250306.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 123  1003ISFL28   HOLD
# 149  1003SFIL28   HOLD
# 193   1015ECL29   SELL
# 221   1015UCL26   SELL
# 265  1018GS2026   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250305.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 122  1003ISFL28   HOLD
# 190   1015ECL29   SELL
# 260  1018GS2026   HOLD
# 271   1025NFL25   SELL
# 337  1025UCL26A   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250304.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 35     0MOFSL27   SELL
# 121  1003ISFL28   HOLD
# 129  1003SCL30A   SELL
# 188   1015ECL29   SELL
# 215   1015UCL26   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250303.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 34     0MOFSL27   SELL
# 119  1003ISFL28   SELL
# 126  1003SCL30A   SELL
# 184   1015ECL29   SELL
# 251  1018GS2026   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250228.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 117  1003ISFL28   SELL
# 180   1015ECL29   SELL
# 206   1015UCL26   SELL
# 246  1018GS2026   HOLD
# 255   1025NFL25   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250227.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 116  1003ISFL28   HOLD
# 178   1015ECL29   SELL
# 181  1015SCL28A   SELL
# 242  1018GS2026   HOLD
# 268   1025SCL34   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250225.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 77   1003IIFL29   HOLD
# 115  1003ISFL28   HOLD
# 138  1003SFIL28   SELL
# 176   1015ECL29   SELL
# 238  1018GS2026   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250224.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 33     0MOFSL27   SELL
# 76   1003IIFL29   SELL
# 113  1003ISFL28   HOLD
# 172   1015ECL29   SELL
# 174  1015SCL28A   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250221.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 74   1003IIFL29   SELL
# 110  1003ISFL28   HOLD
# 168   1015ECL29   SELL
# 175  1015SCL29T   SELL
# 227  1018GS2026   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250220.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 73   1003IIFL29   SELL
# 108  1003ISFL28   HOLD
# 264  1025SCL34Z   SELL
# 284  1025UCL26A   SELL
# 328   1035UCL26   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250219.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 18     0MOFSL26   SELL
# 72   1003IIFL29   SELL
# 106  1003ISFL28   HOLD
# 163   1015ECL29   SELL
# 164  1015SCL28A   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250218.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 70   1003IIFL29   SELL
# 103  1003ISFL28   SELL
# 159   1015ECL29   SELL
# 180   1015UCL26   SELL
# 214  1018GS2026   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250217.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 17     0MOFSL26   SELL
# 69   1003IIFL29   SELL
# 101  1003ISFL28   SELL
# 107  1003SCL30A   SELL
# 123  1003SFIL28   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250214.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 67   1003IIFL29   HOLD
# 98   1003ISFL28   SELL
# 118  1003SFIL28   SELL
# 150   1015ECL29   SELL
# 201  1018GS2026   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250213.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 16     0MOFSL26   SELL
# 96   1003ISFL28   HOLD
# 196  1018GS2026   SELL
# 217   1025SCL34   SELL
# 246   1025UCL25   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250212.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 29     0MOFSL27   SELL
# 65   1003IIFL29   HOLD
# 94   1003ISFL28   SELL
# 144   1015ECL29   SELL
# 163   1015UCL26   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250211.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 63   1003IIFL29   SELL
# 91   1003ISFL28   SELL
# 140   1015ECL29   SELL
# 158   1015UCL26   SELL
# 187  1018GS2026   HOLD
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250210.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 38       0SCL27   SELL
# 62   1003IIFL29   SELL
# 89   1003ISFL28   SELL
# 137   1015ECL29   SELL
# 154   1015UCL26   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250207.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 15     0MOFSL26   SELL
# 28     0MOFSL27   SELL
# 86   1003ISFL28   SELL
# 133   1015ECL29   SELL
# 176  1018GS2026   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250206.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 14     0MOFSL26   SELL
# 26     0MOFSL27   SELL
# 58   1003IIFL29   SELL
# 83   1003ISFL28   SELL
# 102  1003SFIL28   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250205.csv
#
# 🔍 Sample Signal Debug:
#         Symbol Signal
# 13    0MOFSL26   SELL
# 24    0MOFSL27   SELL
# 33      0SCL27   SELL
# 55  1003IIFL29   SELL
# 79  1003ISFL28   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250204.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 12     0MOFSL26   SELL
# 22     0MOFSL27   SELL
# 51   1003IIFL29   SELL
# 74   1003ISFL28   SELL
# 117   1015ECL29   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250203.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 20     0MOFSL27   SELL
# 48   1003IIFL29   SELL
# 70   1003ISFL28   SELL
# 112   1015ECL29   SELL
# 127   1015UCL26   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250131.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 27       0SCL26   SELL
# 46   1003IIFL29   SELL
# 67   1003ISFL28   SELL
# 108   1015ECL29   SELL
# 144  1018GS2026   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250130.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 26       0SCL26   SELL
# 64   1003ISFL28   SELL
# 104   1015ECL29   SELL
# 118   1015UCL26   SELL
# 139  1018GS2026   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250129.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 19     0MOFSL27   SELL
# 43   1003IIFL29   SELL
# 62   1003ISFL28   SELL
# 101   1015ECL29   SELL
# 134  1018GS2026   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250128.csv
#
# 🔍 Sample Signal Debug:
#         Symbol Signal
# 11    0MOFSL26   SELL
# 24      0SCL26   SELL
# 41  1003IIFL29   SELL
# 59  1003ISFL28   SELL
# 97   1015ECL29   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250127.csv
#
# 🔍 Sample Signal Debug:
#          Symbol Signal
# 17     0MOFSL27   SELL
# 38   1003IIFL29   SELL
# 55   1003ISFL28   SELL
# 92    1015ECL29   SELL
# 141  1025SCL34B   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250124.csv
#
# 🔍 Sample Signal Debug:
#         Symbol Signal
# 10    0MOFSL26   SELL
# 16    0MOFSL27   SELL
# 36  1003IIFL29   SELL
# 52  1003ISFL28   HOLD
# 88   1015ECL29   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250123.csv
#
# 🔍 Sample Signal Debug:
#         Symbol Signal
# 19      0SCL26   SELL
# 33  1003IIFL29   SELL
# 48  1003ISFL28   SELL
# 55   1003SCL31   SELL
# 83   1015ECL29   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250122.csv
#
# 🔍 Sample Signal Debug:
#         Symbol Signal
# 9     0MOFSL26   SELL
# 14    0MOFSL27   SELL
# 18      0SCL26   SELL
# 31  1003IIFL29   SELL
# 45  1003ISFL28   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250121.csv
#
# 🔍 Sample Signal Debug:
#         Symbol Signal
# 27  1003IIFL29   SELL
# 45  1003SCL30A   SELL
# 46   1003SCL31   SELL
# 57  1003SFIL28   SELL
# 72   1015ECL29   SELL
# ✅ Signal file saved to: ../signal/nse/equity/2025/20250120.csv
#
# 🔍 Sample Signal Debug:
#         Symbol Signal
# 8     0MOFSL26   SELL
# 12    0MOFSL27   SELL
# 15      0SCL26   SELL
# 26  1003IIFL29   SELL
# 43  1003SCL30A   SELL
# ✅ Rolling signal generation complete.

# %%
base_dir = "../data/nse"
files = list_csv_gz_files(base_dir)
window_size = 60
df = load_rolling_window(files, windows_size)
combined_df = compute_indicators(df)
generate_signals(combined_df, "../signal")

# %%
display_scrollable_df(df, max_rows=30, max_cols=12, height="600px")
