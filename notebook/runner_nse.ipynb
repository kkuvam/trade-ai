# %%
import os
import shutil
import gzip
import pickle
import requests
import zlib
from datetime import datetime
from zipfile import ZipFile
from pathlib import Path
from typing import Union
from datetime import timedelta

# %%
base_url = "https://www.nseindia.com/api"
ARCHIVE_URL = "https://nsearchives.nseindia.com"
cookies_dir = "../data"
output_dir = "../data/nse/equity/nse"
TIMEOUT = 20  # seconds

# %%
HEADERS = {
    "User-Agent": "Mozilla/5.0",
    "Accept": "*/*",
    "Accept-Encoding": "gzip, deflate",
    "Referer": "https://www.nseindia.com"
}

# %%
def get_or_set_cookies(session: requests.Session, cookie_path: Path):
     """
    Loads cookies from a file if it exists; otherwise, fetches them from the NSE website and saves them.

    :param session: The requests.Session object to manage cookies.
    :param cookie_path: The path to the file where cookies are stored or will be saved.
    """
    if cookie_path.exists():
        cookies = pickle.loads(cookie_path.read_bytes())
        session.cookies.update(cookies)
    else:
        response = session.get("https://www.nseindia.com", timeout=TIMEOUT)
        cookies = response.cookies
        cookie_path.write_bytes(pickle.dumps(cookies))
        session.cookies.update(cookies)

# %%
def download_file(session: requests.Session, url: str, dest_path: Path):
    """
    Downloads a file from a given URL and saves it to a specified path.

    :param session: The requests.Session object to use for the download.
    :param url: The URL of the file to download.
    :param dest_path: The local path where the downloaded file will be saved.
    :raises RuntimeError: If the downloaded content is an HTML page, which indicates the file was not found.
    """
    response = session.get(url, stream=True, timeout=TIMEOUT)
    if "text/html" in response.headers.get("Content-Type", ""):
        raise RuntimeError(f"NSE file not available or invalid URL: {url}")

    with open(dest_path, "wb") as f:
        for chunk in response.iter_content(chunk_size=1024 * 1024):
            f.write(chunk)

# %%
def extract_file(file: Path, extract_to: Path) -> Path:
    """
    Extracts the first file from a zip archive, removes the original zip file, and returns the path to the extracted file.

    :param file: The path to the zip file to be extracted.
    :param extract_to: The directory where the file should be extracted.
    :return: The path to the newly extracted file.
    """
    with ZipFile(file) as zipf:
        first_file = zipf.namelist()[0]
        extracted_path = zipf.extract(first_file, path=extract_to)
    file.unlink()  # Remove zip
    return Path(extracted_path)

# %%
def download_nse_equity_bhavcopy(date_str: str, output_dir: Union[str, Path]) -> Path:
    """
    Download and extract NSE equity bhavcopy for a given date.
    :param date_str: Format ddMMMyyyy (e.g., 05AUG2024)
    :param output_dir: Folder to save the extracted CSV
    :return: Path to extracted CSV file
    """
    date_obj = datetime.strptime(date_str.upper(), "%d%b%Y")

    # Ensure output folder
    output_dir = Path(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)
    
    # Setup session and cookies
    session = requests.Session()
    session.headers.update(HEADERS)
    cookie_path = Path(cookies_dir) / "nse_cookies.pkl"
    get_or_set_cookies(session, cookie_path)

    # Download URL and destination
    zip_filename = f"BhavCopy_NSE_CM_0_0_0_{date_obj:%Y%m%d}_F_0000.csv.zip"
    zip_url = f"{ARCHIVE_URL}/content/cm/{zip_filename}"
    zip_path = Path(output_dir) / zip_filename

    # Download and extract
    download_file(session, zip_url, zip_path)
    
    # Extract zip file
    extracted = extract_file(zip_path, output_dir)

    # Rename file
    final_filename = date_obj.strftime("%d%b%Y").upper() + ".csv"
    final_path = output_dir / final_filename
    Path(extracted).rename(final_path)

    # Compress the file to .csv.gz to save space
    gz_path = final_path.with_suffix(".csv.gz")
    with open(final_path, 'rb') as f_in, gzip.open(gz_path, 'wb') as f_out:
        shutil.copyfileobj(f_in, f_out)

    # Optionally remove the uncompressed CSV
    final_path.unlink()  # deletes original .csv file

    print(f"✅ Extracted file saved at: {gz_path}")
    return final_path

# %%
def download_bhavcopy_range(start_date: str, end_date: str, output_dir: Union[str, Path]) -> list:
    """
    Download NSE equity bhavcopies between two dates (inclusive), skipping weekends.

    :param start_date: Start date in ddMMMyyyy (e.g., "01AUG2025")
    :param end_date: End date in ddMMMyyyy (e.g., "05AUG2025")
    :param output_dir: Directory to store downloaded CSVs
    :return: List of Paths to downloaded files
    """
    start = datetime.strptime(start_date.upper(), "%d%b%Y")
    end = datetime.strptime(end_date.upper(), "%d%b%Y")

    current = start
    downloaded_files = []

    while current <= end:
        if current.weekday() < 5:  # 0–4 = Mon–Fri
            date_str = current.strftime("%d%b%Y").upper()
            try:
                file_path = download_nse_equity_bhavcopy(date_str, output_dir)
                downloaded_files.append(file_path)
            except Exception as e:
                print(f"❌ Failed for {date_str}: {e}")
        else:
            print(f"⏭️ Skipping weekend: {current.strftime('%A %d-%b-%Y')}")
        current += timedelta(days=1)

    print(f"✅ Completed. {len(downloaded_files)} files downloaded.")
    return downloaded_files

# %%
download_bhavcopy_range("01JAN2024", "31DEC2024", "../data/nse/equity/2024")
# Out:
# ✅ Extracted file saved at: ../data/nse/equity/2024/01JAN2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/02JAN2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/03JAN2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/04JAN2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/05JAN2024.csv.gz
# ⏭️ Skipping weekend: Saturday 06-Jan-2024
# ⏭️ Skipping weekend: Sunday 07-Jan-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/08JAN2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/09JAN2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/10JAN2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/11JAN2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/12JAN2024.csv.gz
# ⏭️ Skipping weekend: Saturday 13-Jan-2024
# ⏭️ Skipping weekend: Sunday 14-Jan-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/15JAN2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/16JAN2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/17JAN2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/18JAN2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/19JAN2024.csv.gz
# ⏭️ Skipping weekend: Saturday 20-Jan-2024
# ⏭️ Skipping weekend: Sunday 21-Jan-2024
# ❌ Failed for 22JAN2024: NSE file not available or invalid URL: https://nsearchives.nseindia.com/content/cm/BhavCopy_NSE_CM_0_0_0_20240122_F_0000.csv.zip
# ✅ Extracted file saved at: ../data/nse/equity/2024/23JAN2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/24JAN2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/25JAN2024.csv.gz
# ❌ Failed for 26JAN2024: NSE file not available or invalid URL: https://nsearchives.nseindia.com/content/cm/BhavCopy_NSE_CM_0_0_0_20240126_F_0000.csv.zip
# ⏭️ Skipping weekend: Saturday 27-Jan-2024
# ⏭️ Skipping weekend: Sunday 28-Jan-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/29JAN2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/30JAN2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/31JAN2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/01FEB2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/02FEB2024.csv.gz
# ⏭️ Skipping weekend: Saturday 03-Feb-2024
# ⏭️ Skipping weekend: Sunday 04-Feb-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/05FEB2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/06FEB2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/07FEB2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/08FEB2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/09FEB2024.csv.gz
# ⏭️ Skipping weekend: Saturday 10-Feb-2024
# ⏭️ Skipping weekend: Sunday 11-Feb-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/12FEB2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/13FEB2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/14FEB2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/15FEB2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/16FEB2024.csv.gz
# ⏭️ Skipping weekend: Saturday 17-Feb-2024
# ⏭️ Skipping weekend: Sunday 18-Feb-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/19FEB2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/20FEB2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/21FEB2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/22FEB2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/23FEB2024.csv.gz
# ⏭️ Skipping weekend: Saturday 24-Feb-2024
# ⏭️ Skipping weekend: Sunday 25-Feb-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/26FEB2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/27FEB2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/28FEB2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/29FEB2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/01MAR2024.csv.gz
# ⏭️ Skipping weekend: Saturday 02-Mar-2024
# ⏭️ Skipping weekend: Sunday 03-Mar-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/04MAR2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/05MAR2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/06MAR2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/07MAR2024.csv.gz
# ❌ Failed for 08MAR2024: NSE file not available or invalid URL: https://nsearchives.nseindia.com/content/cm/BhavCopy_NSE_CM_0_0_0_20240308_F_0000.csv.zip
# ⏭️ Skipping weekend: Saturday 09-Mar-2024
# ⏭️ Skipping weekend: Sunday 10-Mar-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/11MAR2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/12MAR2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/13MAR2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/14MAR2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/15MAR2024.csv.gz
# ⏭️ Skipping weekend: Saturday 16-Mar-2024
# ⏭️ Skipping weekend: Sunday 17-Mar-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/18MAR2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/19MAR2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/20MAR2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/21MAR2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/22MAR2024.csv.gz
# ⏭️ Skipping weekend: Saturday 23-Mar-2024
# ⏭️ Skipping weekend: Sunday 24-Mar-2024
# ❌ Failed for 25MAR2024: NSE file not available or invalid URL: https://nsearchives.nseindia.com/content/cm/BhavCopy_NSE_CM_0_0_0_20240325_F_0000.csv.zip
# ✅ Extracted file saved at: ../data/nse/equity/2024/26MAR2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/27MAR2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/28MAR2024.csv.gz
# ❌ Failed for 29MAR2024: NSE file not available or invalid URL: https://nsearchives.nseindia.com/content/cm/BhavCopy_NSE_CM_0_0_0_20240329_F_0000.csv.zip
# ⏭️ Skipping weekend: Saturday 30-Mar-2024
# ⏭️ Skipping weekend: Sunday 31-Mar-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/01APR2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/02APR2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/03APR2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/04APR2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/05APR2024.csv.gz
# ⏭️ Skipping weekend: Saturday 06-Apr-2024
# ⏭️ Skipping weekend: Sunday 07-Apr-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/08APR2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/09APR2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/10APR2024.csv.gz
# ❌ Failed for 11APR2024: NSE file not available or invalid URL: https://nsearchives.nseindia.com/content/cm/BhavCopy_NSE_CM_0_0_0_20240411_F_0000.csv.zip
# ✅ Extracted file saved at: ../data/nse/equity/2024/12APR2024.csv.gz
# ⏭️ Skipping weekend: Saturday 13-Apr-2024
# ⏭️ Skipping weekend: Sunday 14-Apr-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/15APR2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/16APR2024.csv.gz
# ❌ Failed for 17APR2024: NSE file not available or invalid URL: https://nsearchives.nseindia.com/content/cm/BhavCopy_NSE_CM_0_0_0_20240417_F_0000.csv.zip
# ✅ Extracted file saved at: ../data/nse/equity/2024/18APR2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/19APR2024.csv.gz
# ⏭️ Skipping weekend: Saturday 20-Apr-2024
# ⏭️ Skipping weekend: Sunday 21-Apr-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/22APR2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/23APR2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/24APR2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/25APR2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/26APR2024.csv.gz
# ⏭️ Skipping weekend: Saturday 27-Apr-2024
# ⏭️ Skipping weekend: Sunday 28-Apr-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/29APR2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/30APR2024.csv.gz
# ❌ Failed for 01MAY2024: NSE file not available or invalid URL: https://nsearchives.nseindia.com/content/cm/BhavCopy_NSE_CM_0_0_0_20240501_F_0000.csv.zip
# ✅ Extracted file saved at: ../data/nse/equity/2024/02MAY2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/03MAY2024.csv.gz
# ⏭️ Skipping weekend: Saturday 04-May-2024
# ⏭️ Skipping weekend: Sunday 05-May-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/06MAY2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/07MAY2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/08MAY2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/09MAY2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/10MAY2024.csv.gz
# ⏭️ Skipping weekend: Saturday 11-May-2024
# ⏭️ Skipping weekend: Sunday 12-May-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/13MAY2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/14MAY2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/15MAY2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/16MAY2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/17MAY2024.csv.gz
# ⏭️ Skipping weekend: Saturday 18-May-2024
# ⏭️ Skipping weekend: Sunday 19-May-2024
# ❌ Failed for 20MAY2024: NSE file not available or invalid URL: https://nsearchives.nseindia.com/content/cm/BhavCopy_NSE_CM_0_0_0_20240520_F_0000.csv.zip
# ✅ Extracted file saved at: ../data/nse/equity/2024/21MAY2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/22MAY2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/23MAY2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/24MAY2024.csv.gz
# ⏭️ Skipping weekend: Saturday 25-May-2024
# ⏭️ Skipping weekend: Sunday 26-May-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/27MAY2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/28MAY2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/29MAY2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/30MAY2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/31MAY2024.csv.gz
# ⏭️ Skipping weekend: Saturday 01-Jun-2024
# ⏭️ Skipping weekend: Sunday 02-Jun-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/03JUN2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/04JUN2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/05JUN2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/06JUN2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/07JUN2024.csv.gz
# ⏭️ Skipping weekend: Saturday 08-Jun-2024
# ⏭️ Skipping weekend: Sunday 09-Jun-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/10JUN2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/11JUN2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/12JUN2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/13JUN2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/14JUN2024.csv.gz
# ⏭️ Skipping weekend: Saturday 15-Jun-2024
# ⏭️ Skipping weekend: Sunday 16-Jun-2024
# ❌ Failed for 17JUN2024: NSE file not available or invalid URL: https://nsearchives.nseindia.com/content/cm/BhavCopy_NSE_CM_0_0_0_20240617_F_0000.csv.zip
# ✅ Extracted file saved at: ../data/nse/equity/2024/18JUN2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/19JUN2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/20JUN2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/21JUN2024.csv.gz
# ⏭️ Skipping weekend: Saturday 22-Jun-2024
# ⏭️ Skipping weekend: Sunday 23-Jun-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/24JUN2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/25JUN2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/26JUN2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/27JUN2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/28JUN2024.csv.gz
# ⏭️ Skipping weekend: Saturday 29-Jun-2024
# ⏭️ Skipping weekend: Sunday 30-Jun-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/01JUL2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/02JUL2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/03JUL2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/04JUL2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/05JUL2024.csv.gz
# ⏭️ Skipping weekend: Saturday 06-Jul-2024
# ⏭️ Skipping weekend: Sunday 07-Jul-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/08JUL2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/09JUL2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/10JUL2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/11JUL2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/12JUL2024.csv.gz
# ⏭️ Skipping weekend: Saturday 13-Jul-2024
# ⏭️ Skipping weekend: Sunday 14-Jul-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/15JUL2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/16JUL2024.csv.gz
# ❌ Failed for 17JUL2024: NSE file not available or invalid URL: https://nsearchives.nseindia.com/content/cm/BhavCopy_NSE_CM_0_0_0_20240717_F_0000.csv.zip
# ✅ Extracted file saved at: ../data/nse/equity/2024/18JUL2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/19JUL2024.csv.gz
# ⏭️ Skipping weekend: Saturday 20-Jul-2024
# ⏭️ Skipping weekend: Sunday 21-Jul-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/22JUL2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/23JUL2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/24JUL2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/25JUL2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/26JUL2024.csv.gz
# ⏭️ Skipping weekend: Saturday 27-Jul-2024
# ⏭️ Skipping weekend: Sunday 28-Jul-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/29JUL2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/30JUL2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/31JUL2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/01AUG2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/02AUG2024.csv.gz
# ⏭️ Skipping weekend: Saturday 03-Aug-2024
# ⏭️ Skipping weekend: Sunday 04-Aug-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/05AUG2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/06AUG2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/07AUG2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/08AUG2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/09AUG2024.csv.gz
# ⏭️ Skipping weekend: Saturday 10-Aug-2024
# ⏭️ Skipping weekend: Sunday 11-Aug-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/12AUG2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/13AUG2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/14AUG2024.csv.gz
# ❌ Failed for 15AUG2024: NSE file not available or invalid URL: https://nsearchives.nseindia.com/content/cm/BhavCopy_NSE_CM_0_0_0_20240815_F_0000.csv.zip
# ✅ Extracted file saved at: ../data/nse/equity/2024/16AUG2024.csv.gz
# ⏭️ Skipping weekend: Saturday 17-Aug-2024
# ⏭️ Skipping weekend: Sunday 18-Aug-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/19AUG2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/20AUG2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/21AUG2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/22AUG2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/23AUG2024.csv.gz
# ⏭️ Skipping weekend: Saturday 24-Aug-2024
# ⏭️ Skipping weekend: Sunday 25-Aug-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/26AUG2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/27AUG2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/28AUG2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/29AUG2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/30AUG2024.csv.gz
# ⏭️ Skipping weekend: Saturday 31-Aug-2024
# ⏭️ Skipping weekend: Sunday 01-Sep-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/02SEP2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/03SEP2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/04SEP2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/05SEP2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/06SEP2024.csv.gz
# ⏭️ Skipping weekend: Saturday 07-Sep-2024
# ⏭️ Skipping weekend: Sunday 08-Sep-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/09SEP2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/10SEP2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/11SEP2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/12SEP2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/13SEP2024.csv.gz
# ⏭️ Skipping weekend: Saturday 14-Sep-2024
# ⏭️ Skipping weekend: Sunday 15-Sep-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/16SEP2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/17SEP2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/18SEP2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/19SEP2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/20SEP2024.csv.gz
# ⏭️ Skipping weekend: Saturday 21-Sep-2024
# ⏭️ Skipping weekend: Sunday 22-Sep-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/23SEP2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/24SEP2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/25SEP2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/26SEP2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/27SEP2024.csv.gz
# ⏭️ Skipping weekend: Saturday 28-Sep-2024
# ⏭️ Skipping weekend: Sunday 29-Sep-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/30SEP2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/01OCT2024.csv.gz
# ❌ Failed for 02OCT2024: NSE file not available or invalid URL: https://nsearchives.nseindia.com/content/cm/BhavCopy_NSE_CM_0_0_0_20241002_F_0000.csv.zip
# ✅ Extracted file saved at: ../data/nse/equity/2024/03OCT2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/04OCT2024.csv.gz
# ⏭️ Skipping weekend: Saturday 05-Oct-2024
# ⏭️ Skipping weekend: Sunday 06-Oct-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/07OCT2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/08OCT2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/09OCT2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/10OCT2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/11OCT2024.csv.gz
# ⏭️ Skipping weekend: Saturday 12-Oct-2024
# ⏭️ Skipping weekend: Sunday 13-Oct-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/14OCT2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/15OCT2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/16OCT2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/17OCT2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/18OCT2024.csv.gz
# ⏭️ Skipping weekend: Saturday 19-Oct-2024
# ⏭️ Skipping weekend: Sunday 20-Oct-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/21OCT2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/22OCT2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/23OCT2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/24OCT2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/25OCT2024.csv.gz
# ⏭️ Skipping weekend: Saturday 26-Oct-2024
# ⏭️ Skipping weekend: Sunday 27-Oct-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/28OCT2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/29OCT2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/30OCT2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/31OCT2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/01NOV2024.csv.gz
# ⏭️ Skipping weekend: Saturday 02-Nov-2024
# ⏭️ Skipping weekend: Sunday 03-Nov-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/04NOV2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/05NOV2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/06NOV2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/07NOV2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/08NOV2024.csv.gz
# ⏭️ Skipping weekend: Saturday 09-Nov-2024
# ⏭️ Skipping weekend: Sunday 10-Nov-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/11NOV2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/12NOV2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/13NOV2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/14NOV2024.csv.gz
# ❌ Failed for 15NOV2024: NSE file not available or invalid URL: https://nsearchives.nseindia.com/content/cm/BhavCopy_NSE_CM_0_0_0_20241115_F_0000.csv.zip
# ⏭️ Skipping weekend: Saturday 16-Nov-2024
# ⏭️ Skipping weekend: Sunday 17-Nov-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/18NOV2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/19NOV2024.csv.gz
# ❌ Failed for 20NOV2024: NSE file not available or invalid URL: https://nsearchives.nseindia.com/content/cm/BhavCopy_NSE_CM_0_0_0_20241120_F_0000.csv.zip
# ✅ Extracted file saved at: ../data/nse/equity/2024/21NOV2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/22NOV2024.csv.gz
# ⏭️ Skipping weekend: Saturday 23-Nov-2024
# ⏭️ Skipping weekend: Sunday 24-Nov-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/25NOV2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/26NOV2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/27NOV2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/28NOV2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/29NOV2024.csv.gz
# ⏭️ Skipping weekend: Saturday 30-Nov-2024
# ⏭️ Skipping weekend: Sunday 01-Dec-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/02DEC2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/03DEC2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/04DEC2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/05DEC2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/06DEC2024.csv.gz
# ⏭️ Skipping weekend: Saturday 07-Dec-2024
# ⏭️ Skipping weekend: Sunday 08-Dec-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/09DEC2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/10DEC2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/11DEC2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/12DEC2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/13DEC2024.csv.gz
# ⏭️ Skipping weekend: Saturday 14-Dec-2024
# ⏭️ Skipping weekend: Sunday 15-Dec-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/16DEC2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/17DEC2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/18DEC2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/19DEC2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/20DEC2024.csv.gz
# ⏭️ Skipping weekend: Saturday 21-Dec-2024
# ⏭️ Skipping weekend: Sunday 22-Dec-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/23DEC2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/24DEC2024.csv.gz
# ❌ Failed for 25DEC2024: NSE file not available or invalid URL: https://nsearchives.nseindia.com/content/cm/BhavCopy_NSE_CM_0_0_0_20241225_F_0000.csv.zip
# ✅ Extracted file saved at: ../data/nse/equity/2024/26DEC2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/27DEC2024.csv.gz
# ⏭️ Skipping weekend: Saturday 28-Dec-2024
# ⏭️ Skipping weekend: Sunday 29-Dec-2024
# ✅ Extracted file saved at: ../data/nse/equity/2024/30DEC2024.csv.gz
# ✅ Extracted file saved at: ../data/nse/equity/2024/31DEC2024.csv.gz
# ✅ Completed. 246 files downloaded.
# [PosixPath('../data/nse/equity/2024/01JAN2024.csv'),
#  PosixPath('../data/nse/equity/2024/02JAN2024.csv'),
#  PosixPath('../data/nse/equity/2024/03JAN2024.csv'),
#  PosixPath('../data/nse/equity/2024/04JAN2024.csv'),
#  PosixPath('../data/nse/equity/2024/05JAN2024.csv'),
#  PosixPath('../data/nse/equity/2024/08JAN2024.csv'),
#  PosixPath('../data/nse/equity/2024/09JAN2024.csv'),
#  PosixPath('../data/nse/equity/2024/10JAN2024.csv'),
#  PosixPath('../data/nse/equity/2024/11JAN2024.csv'),
#  PosixPath('../data/nse/equity/2024/12JAN2024.csv'),
#  PosixPath('../data/nse/equity/2024/15JAN2024.csv'),
#  PosixPath('../data/nse/equity/2024/16JAN2024.csv'),
#  PosixPath('../data/nse/equity/2024/17JAN2024.csv'),
#  PosixPath('../data/nse/equity/2024/18JAN2024.csv'),
#  PosixPath('../data/nse/equity/2024/19JAN2024.csv'),
#  PosixPath('../data/nse/equity/2024/23JAN2024.csv'),
#  PosixPath('../data/nse/equity/2024/24JAN2024.csv'),
#  PosixPath('../data/nse/equity/2024/25JAN2024.csv'),
#  PosixPath('../data/nse/equity/2024/29JAN2024.csv'),
#  PosixPath('../data/nse/equity/2024/30JAN2024.csv'),
#  PosixPath('../data/nse/equity/2024/31JAN2024.csv'),
#  PosixPath('../data/nse/equity/2024/01FEB2024.csv'),
#  PosixPath('../data/nse/equity/2024/02FEB2024.csv'),
#  PosixPath('../data/nse/equity/2024/05FEB2024.csv'),
#  PosixPath('../data/nse/equity/2024/06FEB2024.csv'),
#  PosixPath('../data/nse/equity/2024/07FEB2024.csv'),
#  PosixPath('../data/nse/equity/2024/08FEB2024.csv'),
#  PosixPath('../data/nse/equity/2024/09FEB2024.csv'),
#  PosixPath('../data/nse/equity/2024/12FEB2024.csv'),
#  PosixPath('../data/nse/equity/2024/13FEB2024.csv'),
#  PosixPath('../data/nse/equity/2024/14FEB2024.csv'),
#  PosixPath('../data/nse/equity/2024/15FEB2024.csv'),
#  PosixPath('../data/nse/equity/2024/16FEB2024.csv'),
#  PosixPath('../data/nse/equity/2024/19FEB2024.csv'),
#  PosixPath('../data/nse/equity/2024/20FEB2024.csv'),
#  PosixPath('../data/nse/equity/2024/21FEB2024.csv'),
#  PosixPath('../data/nse/equity/2024/22FEB2024.csv'),
#  PosixPath('../data/nse/equity/2024/23FEB2024.csv'),
#  PosixPath('../data/nse/equity/2024/26FEB2024.csv'),
#  PosixPath('../data/nse/equity/2024/27FEB2024.csv'),
#  PosixPath('../data/nse/equity/2024/28FEB2024.csv'),
#  PosixPath('../data/nse/equity/2024/29FEB2024.csv'),
#  PosixPath('../data/nse/equity/2024/01MAR2024.csv'),
#  PosixPath('../data/nse/equity/2024/04MAR2024.csv'),
#  PosixPath('../data/nse/equity/2024/05MAR2024.csv'),
#  PosixPath('../data/nse/equity/2024/06MAR2024.csv'),
#  PosixPath('../data/nse/equity/2024/07MAR2024.csv'),
#  PosixPath('../data/nse/equity/2024/11MAR2024.csv'),
#  PosixPath('../data/nse/equity/2024/12MAR2024.csv'),
#  PosixPath('../data/nse/equity/2024/13MAR2024.csv'),
#  PosixPath('../data/nse/equity/2024/14MAR2024.csv'),
#  PosixPath('../data/nse/equity/2024/15MAR2024.csv'),
#  PosixPath('../data/nse/equity/2024/18MAR2024.csv'),
#  PosixPath('../data/nse/equity/2024/19MAR2024.csv'),
#  PosixPath('../data/nse/equity/2024/20MAR2024.csv'),
#  PosixPath('../data/nse/equity/2024/21MAR2024.csv'),
#  PosixPath('../data/nse/equity/2024/22MAR2024.csv'),
#  PosixPath('../data/nse/equity/2024/26MAR2024.csv'),
#  PosixPath('../data/nse/equity/2024/27MAR2024.csv'),
#  PosixPath('../data/nse/equity/2024/28MAR2024.csv'),
#  PosixPath('../data/nse/equity/2024/01APR2024.csv'),
#  PosixPath('../data/nse/equity/2024/02APR2024.csv'),
#  PosixPath('../data/nse/equity/2024/03APR2024.csv'),
#  PosixPath('../data/nse/equity/2024/04APR2024.csv'),
#  PosixPath('../data/nse/equity/2024/05APR2024.csv'),
#  PosixPath('../data/nse/equity/2024/08APR2024.csv'),
#  PosixPath('../data/nse/equity/2024/09APR2024.csv'),
#  PosixPath('../data/nse/equity/2024/10APR2024.csv'),
#  PosixPath('../data/nse/equity/2024/12APR2024.csv'),
#  PosixPath('../data/nse/equity/2024/15APR2024.csv'),
#  PosixPath('../data/nse/equity/2024/16APR2024.csv'),
#  PosixPath('../data/nse/equity/2024/18APR2024.csv'),
#  PosixPath('../data/nse/equity/2024/19APR2024.csv'),
#  PosixPath('../data/nse/equity/2024/22APR2024.csv'),
#  PosixPath('../data/nse/equity/2024/23APR2024.csv'),
#  PosixPath('../data/nse/equity/2024/24APR2024.csv'),
#  PosixPath('../data/nse/equity/2024/25APR2024.csv'),
#  PosixPath('../data/nse/equity/2024/26APR2024.csv'),
#  PosixPath('../data/nse/equity/2024/29APR2024.csv'),
#  PosixPath('../data/nse/equity/2024/30APR2024.csv'),
#  PosixPath('../data/nse/equity/2024/02MAY2024.csv'),
#  PosixPath('../data/nse/equity/2024/03MAY2024.csv'),
#  PosixPath('../data/nse/equity/2024/06MAY2024.csv'),
#  PosixPath('../data/nse/equity/2024/07MAY2024.csv'),
#  PosixPath('../data/nse/equity/2024/08MAY2024.csv'),
#  PosixPath('../data/nse/equity/2024/09MAY2024.csv'),
#  PosixPath('../data/nse/equity/2024/10MAY2024.csv'),
#  PosixPath('../data/nse/equity/2024/13MAY2024.csv'),
#  PosixPath('../data/nse/equity/2024/14MAY2024.csv'),
#  PosixPath('../data/nse/equity/2024/15MAY2024.csv'),
#  PosixPath('../data/nse/equity/2024/16MAY2024.csv'),
#  PosixPath('../data/nse/equity/2024/17MAY2024.csv'),
#  PosixPath('../data/nse/equity/2024/21MAY2024.csv'),
#  PosixPath('../data/nse/equity/2024/22MAY2024.csv'),
#  PosixPath('../data/nse/equity/2024/23MAY2024.csv'),
#  PosixPath('../data/nse/equity/2024/24MAY2024.csv'),
#  PosixPath('../data/nse/equity/2024/27MAY2024.csv'),
#  PosixPath('../data/nse/equity/2024/28MAY2024.csv'),
#  PosixPath('../data/nse/equity/2024/29MAY2024.csv'),
#  PosixPath('../data/nse/equity/2024/30MAY2024.csv'),
#  PosixPath('../data/nse/equity/2024/31MAY2024.csv'),
#  PosixPath('../data/nse/equity/2024/03JUN2024.csv'),
#  PosixPath('../data/nse/equity/2024/04JUN2024.csv'),
#  PosixPath('../data/nse/equity/2024/05JUN2024.csv'),
#  PosixPath('../data/nse/equity/2024/06JUN2024.csv'),
#  PosixPath('../data/nse/equity/2024/07JUN2024.csv'),
#  PosixPath('../data/nse/equity/2024/10JUN2024.csv'),
#  PosixPath('../data/nse/equity/2024/11JUN2024.csv'),
#  PosixPath('../data/nse/equity/2024/12JUN2024.csv'),
#  PosixPath('../data/nse/equity/2024/13JUN2024.csv'),
#  PosixPath('../data/nse/equity/2024/14JUN2024.csv'),
#  PosixPath('../data/nse/equity/2024/18JUN2024.csv'),
#  PosixPath('../data/nse/equity/2024/19JUN2024.csv'),
#  PosixPath('../data/nse/equity/2024/20JUN2024.csv'),
#  PosixPath('../data/nse/equity/2024/21JUN2024.csv'),
#  PosixPath('../data/nse/equity/2024/24JUN2024.csv'),
#  PosixPath('../data/nse/equity/2024/25JUN2024.csv'),
#  PosixPath('../data/nse/equity/2024/26JUN2024.csv'),
#  PosixPath('../data/nse/equity/2024/27JUN2024.csv'),
#  PosixPath('../data/nse/equity/2024/28JUN2024.csv'),
#  PosixPath('../data/nse/equity/2024/01JUL2024.csv'),
#  PosixPath('../data/nse/equity/2024/02JUL2024.csv'),
#  PosixPath('../data/nse/equity/2024/03JUL2024.csv'),
#  PosixPath('../data/nse/equity/2024/04JUL2024.csv'),
#  PosixPath('../data/nse/equity/2024/05JUL2024.csv'),
#  PosixPath('../data/nse/equity/2024/08JUL2024.csv'),
#  PosixPath('../data/nse/equity/2024/09JUL2024.csv'),
#  PosixPath('../data/nse/equity/2024/10JUL2024.csv'),
#  PosixPath('../data/nse/equity/2024/11JUL2024.csv'),
#  PosixPath('../data/nse/equity/2024/12JUL2024.csv'),
#  PosixPath('../data/nse/equity/2024/15JUL2024.csv'),
#  PosixPath('../data/nse/equity/2024/16JUL2024.csv'),
#  PosixPath('../data/nse/equity/2024/18JUL2024.csv'),
#  PosixPath('../data/nse/equity/2024/19JUL2024.csv'),
#  PosixPath('../data/nse/equity/2024/22JUL2024.csv'),
#  PosixPath('../data/nse/equity/2024/23JUL2024.csv'),
#  PosixPath('../data/nse/equity/2024/24JUL2024.csv'),
#  PosixPath('../data/nse/equity/2024/25JUL2024.csv'),
#  PosixPath('../data/nse/equity/2024/26JUL2024.csv'),
#  PosixPath('../data/nse/equity/2024/29JUL2024.csv'),
#  PosixPath('../data/nse/equity/2024/30JUL2024.csv'),
#  PosixPath('../data/nse/equity/2024/31JUL2024.csv'),
#  PosixPath('../data/nse/equity/2024/01AUG2024.csv'),
#  PosixPath('../data/nse/equity/2024/02AUG2024.csv'),
#  PosixPath('../data/nse/equity/2024/05AUG2024.csv'),
#  PosixPath('../data/nse/equity/2024/06AUG2024.csv'),
#  PosixPath('../data/nse/equity/2024/07AUG2024.csv'),
#  PosixPath('../data/nse/equity/2024/08AUG2024.csv'),
#  PosixPath('../data/nse/equity/2024/09AUG2024.csv'),
#  PosixPath('../data/nse/equity/2024/12AUG2024.csv'),
#  PosixPath('../data/nse/equity/2024/13AUG2024.csv'),
#  PosixPath('../data/nse/equity/2024/14AUG2024.csv'),
#  PosixPath('../data/nse/equity/2024/16AUG2024.csv'),
#  PosixPath('../data/nse/equity/2024/19AUG2024.csv'),
#  PosixPath('../data/nse/equity/2024/20AUG2024.csv'),
#  PosixPath('../data/nse/equity/2024/21AUG2024.csv'),
#  PosixPath('../data/nse/equity/2024/22AUG2024.csv'),
#  PosixPath('../data/nse/equity/2024/23AUG2024.csv'),
#  PosixPath('../data/nse/equity/2024/26AUG2024.csv'),
#  PosixPath('../data/nse/equity/2024/27AUG2024.csv'),
#  PosixPath('../data/nse/equity/2024/28AUG2024.csv'),
#  PosixPath('../data/nse/equity/2024/29AUG2024.csv'),
#  PosixPath('../data/nse/equity/2024/30AUG2024.csv'),
#  PosixPath('../data/nse/equity/2024/02SEP2024.csv'),
#  PosixPath('../data/nse/equity/2024/03SEP2024.csv'),
#  PosixPath('../data/nse/equity/2024/04SEP2024.csv'),
#  PosixPath('../data/nse/equity/2024/05SEP2024.csv'),
#  PosixPath('../data/nse/equity/2024/06SEP2024.csv'),
#  PosixPath('../data/nse/equity/2024/09SEP2024.csv'),
#  PosixPath('../data/nse/equity/2024/10SEP2024.csv'),
#  PosixPath('../data/nse/equity/2024/11SEP2024.csv'),
#  PosixPath('../data/nse/equity/2024/12SEP2024.csv'),
#  PosixPath('../data/nse/equity/2024/13SEP2024.csv'),
#  PosixPath('../data/nse/equity/2024/16SEP2024.csv'),
#  PosixPath('../data/nse/equity/2024/17SEP2024.csv'),
#  PosixPath('../data/nse/equity/2024/18SEP2024.csv'),
#  PosixPath('../data/nse/equity/2024/19SEP2024.csv'),
#  PosixPath('../data/nse/equity/2024/20SEP2024.csv'),
#  PosixPath('../data/nse/equity/2024/23SEP2024.csv'),
#  PosixPath('../data/nse/equity/2024/24SEP2024.csv'),
#  PosixPath('../data/nse/equity/2024/25SEP2024.csv'),
#  PosixPath('../data/nse/equity/2024/26SEP2024.csv'),
#  PosixPath('../data/nse/equity/2024/27SEP2024.csv'),
#  PosixPath('../data/nse/equity/2024/30SEP2024.csv'),
#  PosixPath('../data/nse/equity/2024/01OCT2024.csv'),
#  PosixPath('../data/nse/equity/2024/03OCT2024.csv'),
#  PosixPath('../data/nse/equity/2024/04OCT2024.csv'),
#  PosixPath('../data/nse/equity/2024/07OCT2024.csv'),
#  PosixPath('../data/nse/equity/2024/08OCT2024.csv'),
#  PosixPath('../data/nse/equity/2024/09OCT2024.csv'),
#  PosixPath('../data/nse/equity/2024/10OCT2024.csv'),
#  PosixPath('../data/nse/equity/2024/11OCT2024.csv'),
#  PosixPath('../data/nse/equity/2024/14OCT2024.csv'),
#  PosixPath('../data/nse/equity/2024/15OCT2024.csv'),
#  PosixPath('../data/nse/equity/2024/16OCT2024.csv'),
#  PosixPath('../data/nse/equity/2024/17OCT2024.csv'),
#  PosixPath('../data/nse/equity/2024/18OCT2024.csv'),
#  PosixPath('../data/nse/equity/2024/21OCT2024.csv'),
#  PosixPath('../data/nse/equity/2024/22OCT2024.csv'),
#  PosixPath('../data/nse/equity/2024/23OCT2024.csv'),
#  PosixPath('../data/nse/equity/2024/24OCT2024.csv'),
#  PosixPath('../data/nse/equity/2024/25OCT2024.csv'),
#  PosixPath('../data/nse/equity/2024/28OCT2024.csv'),
#  PosixPath('../data/nse/equity/2024/29OCT2024.csv'),
#  PosixPath('../data/nse/equity/2024/30OCT2024.csv'),
#  PosixPath('../data/nse/equity/2024/31OCT2024.csv'),
#  PosixPath('../data/nse/equity/2024/01NOV2024.csv'),
#  PosixPath('../data/nse/equity/2024/04NOV2024.csv'),
#  PosixPath('../data/nse/equity/2024/05NOV2024.csv'),
#  PosixPath('../data/nse/equity/2024/06NOV2024.csv'),
#  PosixPath('../data/nse/equity/2024/07NOV2024.csv'),
#  PosixPath('../data/nse/equity/2024/08NOV2024.csv'),
#  PosixPath('../data/nse/equity/2024/11NOV2024.csv'),
#  PosixPath('../data/nse/equity/2024/12NOV2024.csv'),
#  PosixPath('../data/nse/equity/2024/13NOV2024.csv'),
#  PosixPath('../data/nse/equity/2024/14NOV2024.csv'),
#  PosixPath('../data/nse/equity/2024/18NOV2024.csv'),
#  PosixPath('../data/nse/equity/2024/19NOV2024.csv'),
#  PosixPath('../data/nse/equity/2024/21NOV2024.csv'),
#  PosixPath('../data/nse/equity/2024/22NOV2024.csv'),
#  PosixPath('../data/nse/equity/2024/25NOV2024.csv'),
#  PosixPath('../data/nse/equity/2024/26NOV2024.csv'),
#  PosixPath('../data/nse/equity/2024/27NOV2024.csv'),
#  PosixPath('../data/nse/equity/2024/28NOV2024.csv'),
#  PosixPath('../data/nse/equity/2024/29NOV2024.csv'),
#  PosixPath('../data/nse/equity/2024/02DEC2024.csv'),
#  PosixPath('../data/nse/equity/2024/03DEC2024.csv'),
#  PosixPath('../data/nse/equity/2024/04DEC2024.csv'),
#  PosixPath('../data/nse/equity/2024/05DEC2024.csv'),
#  PosixPath('../data/nse/equity/2024/06DEC2024.csv'),
#  PosixPath('../data/nse/equity/2024/09DEC2024.csv'),
#  PosixPath('../data/nse/equity/2024/10DEC2024.csv'),
#  PosixPath('../data/nse/equity/2024/11DEC2024.csv'),
#  PosixPath('../data/nse/equity/2024/12DEC2024.csv'),
#  PosixPath('../data/nse/equity/2024/13DEC2024.csv'),
#  PosixPath('../data/nse/equity/2024/16DEC2024.csv'),
#  PosixPath('../data/nse/equity/2024/17DEC2024.csv'),
#  PosixPath('../data/nse/equity/2024/18DEC2024.csv'),
#  PosixPath('../data/nse/equity/2024/19DEC2024.csv'),
#  PosixPath('../data/nse/equity/2024/20DEC2024.csv'),
#  PosixPath('../data/nse/equity/2024/23DEC2024.csv'),
#  PosixPath('../data/nse/equity/2024/24DEC2024.csv'),
#  PosixPath('../data/nse/equity/2024/26DEC2024.csv'),
#  PosixPath('../data/nse/equity/2024/27DEC2024.csv'),
#  PosixPath('../data/nse/equity/2024/30DEC2024.csv'),
#  PosixPath('../data/nse/equity/2024/31DEC2024.csv')]
